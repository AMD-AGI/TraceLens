# %%
from tqdm import tqdm
from pprint import pprint
import json
import pandas as pd
import sys
sys.path.append('/home/ajassani/iLoveTrace')
from Trace2Tree.trace_to_tree import TraceToTree
from tree_perf import TreePerfAnalyzer

# %%
# path = "/content/pytorch_profile_rank7_step120.json"
path = "/home/ajassani/trace_data/pytorch_profile_gpt-3-large-segmentation_ddp_bfloat16_bs10_level1_rank0.json"
# path = '/home/ajassani/trace_data/wide_resnet101_2.json'
with open(path, 'r') as f:
    data = json.load(f)

events = data['traceEvents']
tree = TraceToTree(events)
tree.build_tree(add_python_func=False)
perf_analyzer = TreePerfAnalyzer(tree)
# Out:
# Building tree with add_python_func=False
# Building CPU op tree with add_python_func=False

# %%
linear_root_nodes = [node for node in tree.cpu_root_nodes if tree.events_by_uid[node]['name'] == 'aten::linear']
print(f"Found {len(linear_root_nodes)} root nodes")

df_linear_ops = perf_analyzer.build_df_perf_metrics(linear_root_nodes, bwd=False)
perf_analyzer.summarize_df_perf_metrics(df_linear_ops, ['mean'])
# Out:
# Found 149 root nodes
#            name  param: M  param: N  param: K  param: bias  GFLOPS_first  \
# 0  aten::linear     40960      1536      1536         True    193.336443
# 2  aten::linear     40960      6144      1536         True    773.345772
# 1  aten::linear     40960      1536      6144         True    773.157028
# 3  aten::linear     41400      1536      1536         True    195.413299
# 4  aten::linear     48000        64      1536         True      9.440256
#
#    FLOPS/Byte_first  TFLOPS/s_mean  Kernel Time (µs)_sum  name_count
# 0        754.101394     261.342643                 73298          98
# 2       1193.375429     364.628983                 50908          24
# 1       1193.101140     438.162555                 42408          24
# 3        754.249025     151.975030                  2572           2
# 4         61.381381      27.765459                   340           1

# %%
linear_root_nodes = [node for node in tree.cpu_root_nodes if tree.events_by_uid[node]['name'] == 'aten::linear']
uid = linear_root_nodes[0]
event = tree.events_by_uid[uid]
perf_analyzer.compute_fwd_perf_metrics(event)
# Out:
# {'GFLOPS': 193.33644288,
#  'Kernel Time (µs)': 778,
#  'TFLOPS/s': 248.5044252956298,
#  'FLOPS/Byte': 754.1013935319985,
#  'param: M': 40960,
#  'param: N': 1536,
#  'param: K': 1536,
#  'param: bias': True}

# %%
df_linear_ops
# Out:
#         cat          name    pid    tid  external_id      GFLOPS  \
# 0    cpu_op  aten::linear  17178  17178         9103  193.336443
# 1    cpu_op  aten::linear  17178  17178         9126  195.413299
# 2    cpu_op  aten::linear  17178  17178         9149  195.413299
# 3    cpu_op  aten::linear  17178  17178         9190  193.336443
# 4    cpu_op  aten::linear  17178  17178         9209  193.336443
# ..      ...           ...    ...    ...          ...         ...
# 144  cpu_op  aten::linear  17178  17178        13525  193.336443
# 145  cpu_op  aten::linear  17178  17178        13566  193.336443
# 146  cpu_op  aten::linear  17178  17178        13600  773.345772
# 147  cpu_op  aten::linear  17178  17178        13631  773.157028
# 148  cpu_op  aten::linear  17178  17178        13669    9.440256
#
#      Kernel Time (µs)    TFLOPS/s   FLOPS/Byte  param: M  param: N  param: K  \
# 0                 778  248.504425   754.101394     40960      1536      1536
# 1                1301  150.202382   754.249025     41400      1536      1536
# 2                1271  153.747678   754.249025     41400      1536      1536
# 3                 629  307.371133   754.101394     40960      1536      1536
# 4                 593  326.031101   754.101394     40960      1536      1536
# ..                ...         ...          ...       ...       ...       ...
# 144               735  263.042779   754.101394     40960      1536      1536
# 145               650  297.440681   754.101394     40960      1536      1536
# 146              2120  364.785741  1193.375429     40960      6144      1536
# 147              1824  423.879949  1193.101140     40960      1536      6144
# 148               340   27.765459    61.381381     48000        64      1536
#
#      param: bias
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True
# ..           ...
# 144         True
# 145         True
# 146         True
# 147         True
# 148         True
#
# [149 rows x 13 columns]

# %%
# linear bwd metrics
df_linear_bwd_ops = perf_analyzer.build_df_perf_metrics(linear_root_nodes, bwd=True)
perf_analyzer.summarize_df_perf_metrics(df_linear_bwd_ops, ['mean'])
# Out:
#            name  param: M  param: N  param: K  param: bias  GFLOPS_first  \
# 0  aten::linear     40960      1536      1536         True    386.609971
# 2  aten::linear     40960      6144      1536         True   1546.439885
# 1  aten::linear     40960      1536      6144         True   1546.251141
# 3  aten::linear     41400      1536      1536         True    390.763008
# 4  aten::linear     48000        64      1536         True     18.877440
#
#    FLOPS/Byte_first  TFLOPS/s_mean  Kernel Time (µs)_sum  name_count
# 0        671.584699     212.946378                179200          98
# 2        999.186992     325.697734                114028          24
# 1       1137.824074     340.815388                109205          24
# 3        671.701730     237.908783                  3292           2
# 4         60.764576      27.279538                   692           1

# %%
# flash attention metrics
fa_root_nodes = [node for node in tree.cpu_root_nodes if tree.events_by_uid[node]['name'] == 'FlashAttnFunc']
print(f"Found {len(fa_root_nodes)} root nodes")
df_fa_fwd_ops = perf_analyzer.build_df_perf_metrics(fa_root_nodes, bwd=False)
perf_analyzer.summarize_df_perf_metrics(df_fa_fwd_ops, ['mean'])
# Out:
# Found 25 root nodes
#             name  param: B  param: N_Q  param: N_K  param: H  param: d_k  \
# 0  FlashAttnFunc        10        4096        4096        16          96
# 1  FlashAttnFunc        10        4096        4140        16          96
#
#    param: dropout  param: causal  param: flash_impl  GFLOPS_first  \
# 0             0.0          False               True   1030.792151
# 1             0.0          False               True   1041.865114
#
#    FLOPS/Byte_first  TFLOPS/s_mean  Kernel Time (µs)_sum  name_count
# 0       2048.000000     303.081004                 81653          24
# 1       2058.941234     286.305335                  3639           1

# %%
# flash attention bwd metrics
df_fa_bwd_ops = perf_analyzer.build_df_perf_metrics(fa_root_nodes, bwd=True)
perf_analyzer.summarize_df_perf_metrics(df_fa_bwd_ops, ['mean'])
# Out:
#             name  param: B  param: N_Q  param: N_K  param: H  param: d_k  \
# 0  FlashAttnFunc        10        4096        4096        16          96
# 1  FlashAttnFunc        10        4096        4140        16          96
#
#    param: dropout  param: causal  param: flash_impl  GFLOPS_first  \
# 0             0.0          False               True   2576.980378
# 1             0.0          False               True   2604.662784
#
#    TFLOPS/s_mean  Kernel Time (µs)_sum  name_count
# 0     134.131422                461134          24
# 1     131.184225                 19855           1

# %%
conv2d_root_nodes = [node for node in tree.cpu_root_nodes if tree.events_by_uid[node]['name'] == 'aten::conv2d']
print(f"Found {len(conv2d_root_nodes)} root nodes")

df_conv2d_ops = perf_analyzer.build_df_perf_metrics(conv2d_root_nodes, bwd=False)
perf_analyzer.summarize_df_perf_metrics(df_conv2d_ops, ['mean'])
# Out:
# Found 276 root nodes
#             name   param: input_shape param: filter_shape param: stride  \
# 28  aten::conv2d    (10, 896, 59, 91)    (896, 896, 1, 1)        (1, 1)
# 27  aten::conv2d    (10, 896, 59, 91)     (896, 56, 3, 3)        (1, 1)
# 17  aten::conv2d  (10, 224, 469, 724)     (224, 56, 3, 3)        (2, 2)
# 20  aten::conv2d  (10, 448, 118, 181)     (448, 56, 3, 3)        (1, 1)
# 14  aten::conv2d  (10, 224, 235, 362)    (224, 224, 1, 1)        (1, 1)
# 13  aten::conv2d  (10, 224, 235, 362)     (224, 56, 3, 3)        (1, 1)
# 21  aten::conv2d  (10, 448, 118, 181)    (448, 448, 1, 1)        (1, 1)
# 24  aten::conv2d  (10, 448, 235, 362)     (448, 56, 3, 3)        (2, 2)
# 15  aten::conv2d  (10, 224, 235, 362)    (448, 224, 1, 1)        (1, 1)
# 3   aten::conv2d   (10, 32, 469, 724)     (224, 32, 1, 1)        (1, 1)
# 31  aten::conv2d  (10, 896, 118, 181)     (896, 56, 3, 3)        (2, 2)
# 4   aten::conv2d   (10, 32, 469, 724)     (224, 32, 1, 1)        (2, 2)
# 16  aten::conv2d  (10, 224, 235, 362)    (448, 224, 1, 1)        (2, 2)
# 29  aten::conv2d    (10, 896, 59, 91)   (2016, 896, 1, 1)        (1, 1)
# 22  aten::conv2d  (10, 448, 118, 181)    (896, 448, 1, 1)        (1, 1)
# 35  aten::conv2d   (10, 2016, 59, 91)    (2016, 56, 3, 3)        (2, 2)
# 0   aten::conv2d   (10, 3, 938, 1448)       (32, 3, 3, 3)        (2, 2)
# 34  aten::conv2d   (10, 2016, 30, 46)  (2016, 2016, 1, 1)        (1, 1)
# 33  aten::conv2d   (10, 2016, 30, 46)  (1536, 2016, 1, 1)        (1, 1)
# 1   aten::conv2d   (10, 4, 938, 1448)        (3, 4, 1, 1)        (1, 1)
# 26  aten::conv2d      (10, 896, 1, 1)    (224, 896, 1, 1)        (1, 1)
# 30  aten::conv2d    (10, 896, 59, 91)   (2016, 896, 1, 1)        (2, 2)
# 23  aten::conv2d  (10, 448, 118, 181)    (896, 448, 1, 1)        (2, 2)
# 11  aten::conv2d      (10, 224, 1, 1)    (896, 224, 1, 1)        (1, 1)
# 19  aten::conv2d      (10, 448, 1, 1)    (112, 448, 1, 1)        (1, 1)
# 7   aten::conv2d      (10, 112, 1, 1)    (448, 112, 1, 1)        (1, 1)
# 32  aten::conv2d     (10, 2016, 1, 1)   (224, 2016, 1, 1)        (1, 1)
# 25  aten::conv2d      (10, 896, 1, 1)    (112, 896, 1, 1)        (1, 1)
# 18  aten::conv2d      (10, 448, 1, 1)     (56, 448, 1, 1)        (1, 1)
# 2   aten::conv2d        (10, 8, 1, 1)      (224, 8, 1, 1)        (1, 1)
# 9   aten::conv2d      (10, 224, 1, 1)      (8, 224, 1, 1)        (1, 1)
# 8   aten::conv2d      (10, 112, 1, 1)    (896, 112, 1, 1)        (1, 1)
# 12  aten::conv2d      (10, 224, 1, 1)   (2016, 224, 1, 1)        (1, 1)
# 6   aten::conv2d       (10, 56, 1, 1)     (448, 56, 1, 1)        (1, 1)
# 5   aten::conv2d       (10, 56, 1, 1)     (224, 56, 1, 1)        (1, 1)
# 10  aten::conv2d      (10, 224, 1, 1)     (56, 224, 1, 1)        (1, 1)
#
#    param: padding param: dilation  param: groups  param: bias  \
# 28         (0, 0)          (1, 1)              1        False
# 27         (1, 1)          (1, 1)             16        False
# 17         (1, 1)          (1, 1)              4        False
# 20         (1, 1)          (1, 1)              8        False
# 14         (0, 0)          (1, 1)              1        False
# 13         (1, 1)          (1, 1)              4        False
# 21         (0, 0)          (1, 1)              1        False
# 24         (1, 1)          (1, 1)              8        False
# 15         (0, 0)          (1, 1)              1        False
# 3          (0, 0)          (1, 1)              1        False
# 31         (1, 1)          (1, 1)             16        False
# 4          (0, 0)          (1, 1)              1        False
# 16         (0, 0)          (1, 1)              1        False
# 29         (0, 0)          (1, 1)              1        False
# 22         (0, 0)          (1, 1)              1        False
# 35         (1, 1)          (1, 1)             36        False
# 0          (1, 1)          (1, 1)              1        False
# 34         (0, 0)          (1, 1)              1        False
# 33         (0, 0)          (1, 1)              1        False
# 1          (0, 0)          (1, 1)              1        False
# 26         (0, 0)          (1, 1)              1        False
# 30         (0, 0)          (1, 1)              1        False
# 23         (0, 0)          (1, 1)              1        False
# 11         (0, 0)          (1, 1)              1        False
# 19         (0, 0)          (1, 1)              1        False
# 7          (0, 0)          (1, 1)              1        False
# 32         (0, 0)          (1, 1)              1        False
# 25         (0, 0)          (1, 1)              1        False
# 18         (0, 0)          (1, 1)              1        False
# 2          (0, 0)          (1, 1)              1        False
# 9          (0, 0)          (1, 1)              1        False
# 8          (0, 0)          (1, 1)              1        False
# 12         (0, 0)          (1, 1)              1        False
# 6          (0, 0)          (1, 1)              1        False
# 5          (0, 0)          (1, 1)              1        False
# 10         (0, 0)          (1, 1)              1        False
#
#     param: transposed_conv  GFLOPS_first  FLOPS/Byte_first  TFLOPS/s_mean  \
# 28                   False     86.206382        444.292733     206.430882
# 27                   False     48.491090        250.822736      97.645955
# 17                   False    192.081254        100.959884      45.274699
# 20                   False     96.449311        251.703019      82.544592
# 14                   False     85.369446        111.985256      95.731039
# 13                   False    192.081254        251.925373      72.977839
# 21                   False     85.732721        223.765318     245.430713
# 24                   False     96.449311        101.094983      46.897823
# 15                   False    170.738893        149.307124     133.117671
# 3                    False     48.678748         27.999769      39.907164
# 31                   False     48.491090        101.054471      48.787691
# 4                    False     12.195635         20.378916      14.586359
# 16                   False     42.866360         74.851945      78.889507
# 29                   False    193.964360        613.222819     371.761299
# 22                   False    171.465441        298.249599     329.248129
# 35                   False     28.043366        102.291379      57.231838
# 0                    False      5.867528         19.636250      13.367391
# 34                   False    112.173466        939.384117     262.252873
# 33                   False     85.465498        819.983200     205.610744
# 1                    False      0.325974          1.714285       0.816782
# 26                   False      0.004014          9.471459       0.100615
# 30                   False     49.854874        320.678685     177.982215
# 23                   False     43.103191        149.465102     161.198983
# 11                   False      0.004014          9.471459       0.137062
# 19                   False      0.001004          8.995984       0.030577
# 7                    False      0.001004          8.995984       0.031180
# 32                   False      0.009032          9.527410       0.131727
# 25                   False      0.002007          9.087221       0.045030
# 18                   False      0.000502          8.327138       0.013812
# 2                    False      0.000036          4.357977       0.001002
# 9                    False      0.000036          4.357977       0.001057
# 8                    False      0.002007          9.087221       0.062250
# 12                   False      0.009032          9.527410       0.289978
# 6                    False      0.000502          8.327138       0.016017
# 5                    False      0.000251          8.175182       0.008195
# 10                   False      0.000251          8.175182       0.008888
#
#     Kernel Time (µs)_sum  name_count
# 28                 23920          57
# 27                 13426          27
# 17                 12729           3
# 20                 10522           9
# 14                  8075           9
# 13                  7897           3
# 21                  7350          21
# 24                  6170           3
# 15                  3848           3
# 3                   3662           3
# 31                  2984           3
# 4                   2511           3
# 16                  1632           3
# 29                  1566           3
# 22                  1563           3
# 35                  1470           3
# 0                   1317           3
# 34                  1284           3
# 33                  1250           3
# 1                   1206           3
# 26                  1080          27
# 30                   841           3
# 23                   803           3
# 11                   795          27
# 19                   296           9
# 7                    291           9
# 32                   206           3
# 25                   134           3
# 18                   109           3
# 2                    108           3
# 9                    102           3
# 8                     97           3
# 12                    94           3
# 6                     94           3
# 5                     92           3
# 10                    85           3

# %%
# conv2d bwd 
df_conv2d_bwd_ops = perf_analyzer.build_df_perf_metrics(conv2d_root_nodes, bwd=True)
perf_analyzer.summarize_df_perf_metrics(df_conv2d_bwd_ops, ['mean'])
# Out:
#             name   param: input_shape param: filter_shape param: stride  \
# 28  aten::conv2d    (10, 896, 59, 91)    (896, 896, 1, 1)        (1, 1)
# 17  aten::conv2d  (10, 224, 469, 724)     (224, 56, 3, 3)        (2, 2)
# 27  aten::conv2d    (10, 896, 59, 91)     (896, 56, 3, 3)        (1, 1)
# 20  aten::conv2d  (10, 448, 118, 181)     (448, 56, 3, 3)        (1, 1)
# 21  aten::conv2d  (10, 448, 118, 181)    (448, 448, 1, 1)        (1, 1)
# 14  aten::conv2d  (10, 224, 235, 362)    (224, 224, 1, 1)        (1, 1)
# 13  aten::conv2d  (10, 224, 235, 362)     (224, 56, 3, 3)        (1, 1)
# 24  aten::conv2d  (10, 448, 235, 362)     (448, 56, 3, 3)        (2, 2)
# 3   aten::conv2d   (10, 32, 469, 724)     (224, 32, 1, 1)        (1, 1)
# 15  aten::conv2d  (10, 224, 235, 362)    (448, 224, 1, 1)        (1, 1)
# 31  aten::conv2d  (10, 896, 118, 181)     (896, 56, 3, 3)        (2, 2)
# 4   aten::conv2d   (10, 32, 469, 724)     (224, 32, 1, 1)        (2, 2)
# 16  aten::conv2d  (10, 224, 235, 362)    (448, 224, 1, 1)        (2, 2)
# 0   aten::conv2d   (10, 3, 938, 1448)       (32, 3, 3, 3)        (2, 2)
# 22  aten::conv2d  (10, 448, 118, 181)    (896, 448, 1, 1)        (1, 1)
# 29  aten::conv2d    (10, 896, 59, 91)   (2016, 896, 1, 1)        (1, 1)
# 23  aten::conv2d  (10, 448, 118, 181)    (896, 448, 1, 1)        (2, 2)
# 35  aten::conv2d   (10, 2016, 59, 91)    (2016, 56, 3, 3)        (2, 2)
# 33  aten::conv2d   (10, 2016, 30, 46)  (1536, 2016, 1, 1)        (1, 1)
# 34  aten::conv2d   (10, 2016, 30, 46)  (2016, 2016, 1, 1)        (1, 1)
# 1   aten::conv2d   (10, 4, 938, 1448)        (3, 4, 1, 1)        (1, 1)
# 30  aten::conv2d    (10, 896, 59, 91)   (2016, 896, 1, 1)        (2, 2)
# 26  aten::conv2d      (10, 896, 1, 1)    (224, 896, 1, 1)        (1, 1)
# 11  aten::conv2d      (10, 224, 1, 1)    (896, 224, 1, 1)        (1, 1)
# 7   aten::conv2d      (10, 112, 1, 1)    (448, 112, 1, 1)        (1, 1)
# 19  aten::conv2d      (10, 448, 1, 1)    (112, 448, 1, 1)        (1, 1)
# 18  aten::conv2d      (10, 448, 1, 1)     (56, 448, 1, 1)        (1, 1)
# 25  aten::conv2d      (10, 896, 1, 1)    (112, 896, 1, 1)        (1, 1)
# 8   aten::conv2d      (10, 112, 1, 1)    (896, 112, 1, 1)        (1, 1)
# 6   aten::conv2d       (10, 56, 1, 1)     (448, 56, 1, 1)        (1, 1)
# 9   aten::conv2d      (10, 224, 1, 1)      (8, 224, 1, 1)        (1, 1)
# 12  aten::conv2d      (10, 224, 1, 1)   (2016, 224, 1, 1)        (1, 1)
# 2   aten::conv2d        (10, 8, 1, 1)      (224, 8, 1, 1)        (1, 1)
# 5   aten::conv2d       (10, 56, 1, 1)     (224, 56, 1, 1)        (1, 1)
# 10  aten::conv2d      (10, 224, 1, 1)     (56, 224, 1, 1)        (1, 1)
# 32  aten::conv2d     (10, 2016, 1, 1)   (224, 2016, 1, 1)        (1, 1)
#
#    param: padding param: dilation  param: groups  param: bias  \
# 28         (0, 0)          (1, 1)              1        False
# 17         (1, 1)          (1, 1)              4        False
# 27         (1, 1)          (1, 1)             16        False
# 20         (1, 1)          (1, 1)              8        False
# 21         (0, 0)          (1, 1)              1        False
# 14         (0, 0)          (1, 1)              1        False
# 13         (1, 1)          (1, 1)              4        False
# 24         (1, 1)          (1, 1)              8        False
# 3          (0, 0)          (1, 1)              1        False
# 15         (0, 0)          (1, 1)              1        False
# 31         (1, 1)          (1, 1)             16        False
# 4          (0, 0)          (1, 1)              1        False
# 16         (0, 0)          (1, 1)              1        False
# 0          (1, 1)          (1, 1)              1        False
# 22         (0, 0)          (1, 1)              1        False
# 29         (0, 0)          (1, 1)              1        False
# 23         (0, 0)          (1, 1)              1        False
# 35         (1, 1)          (1, 1)             36        False
# 33         (0, 0)          (1, 1)              1        False
# 34         (0, 0)          (1, 1)              1        False
# 1          (0, 0)          (1, 1)              1        False
# 30         (0, 0)          (1, 1)              1        False
# 26         (0, 0)          (1, 1)              1        False
# 11         (0, 0)          (1, 1)              1        False
# 7          (0, 0)          (1, 1)              1        False
# 19         (0, 0)          (1, 1)              1        False
# 18         (0, 0)          (1, 1)              1        False
# 25         (0, 0)          (1, 1)              1        False
# 8          (0, 0)          (1, 1)              1        False
# 6          (0, 0)          (1, 1)              1        False
# 9          (0, 0)          (1, 1)              1        False
# 12         (0, 0)          (1, 1)              1        False
# 2          (0, 0)          (1, 1)              1        False
# 5          (0, 0)          (1, 1)              1        False
# 10         (0, 0)          (1, 1)              1        False
# 32         (0, 0)          (1, 1)              1        False
#
#     param: transposed_conv  GFLOPS_first  FLOPS/Byte_first  TFLOPS/s_mean  \
# 28                   False    172.412764        444.292733     204.136473
# 17                   False    384.162509        100.959884      31.997011
# 27                   False     96.982180        250.822736      85.186251
# 20                   False    192.898621        251.703019      69.197994
# 21                   False    171.465441        223.765318     146.426581
# 14                   False    170.738893        111.985256      85.029022
# 13                   False    384.162509        251.925373      67.152075
# 24                   False    192.898621        101.094983      33.881520
# 3                    False     97.357496         27.999769      18.308031
# 15                   False    341.477786        149.307124     126.570726
# 31                   False     96.982180        101.054471      41.666435
# 4                    False     24.391270         20.378916      11.582228
# 16                   False     85.732721         74.851945      41.555999
# 0                    False     11.735055         19.636250       6.072263
# 22                   False    342.930883        298.249599     184.509637
# 29                   False    387.928719        613.222819     221.237173
# 23                   False     86.206382        149.465102      65.927105
# 35                   False     56.086733        102.291379      43.069028
# 33                   False    170.930995        819.983200     141.422175
# 34                   False    224.346931        939.384117     239.468147
# 1                    False      0.651948          1.714285       0.840397
# 30                   False     99.709747        320.678685     137.485527
# 26                   False      0.008028          9.471459       0.121095
# 11                   False      0.008028          9.471459       0.149114
# 7                    False      0.002007          8.995984       0.034638
# 19                   False      0.002007          8.995984       0.035619
# 18                   False      0.001004          8.327138       0.014586
# 25                   False      0.004014          9.087221       0.062211
# 8                    False      0.004014          9.087221       0.072145
# 6                    False      0.001004          8.327138       0.018362
# 9                    False      0.000072          4.357977       0.001320
# 12                   False      0.018063          9.527410       0.361968
# 2                    False      0.000072          4.357977       0.001464
# 5                    False      0.000502          8.175182       0.010248
# 10                   False      0.000502          8.175182       0.010492
# 32                   False      0.018063          9.527410       0.458095
#
#     Kernel Time (µs)_sum  name_count
# 28                 48518          57
# 17                 36019           3
# 27                 30777          27
# 20                 25102           9
# 21                 24808          21
# 14                 18183           9
# 13                 17163           3
# 24                 17080           3
# 3                  15955           3
# 15                  8097           3
# 31                  6984           3
# 4                   6318           3
# 16                  6190           3
# 0                   5803           3
# 22                  5622           3
# 29                  5261           3
# 23                  3926           3
# 35                  3907           3
# 33                  3626           3
# 34                  2834           3
# 1                   2328           3
# 30                  2176           3
# 26                  1800          27
# 11                  1476          27
# 7                    537           9
# 19                   509           9
# 18                   216           3
# 25                   195           3
# 8                    168           3
# 6                    166           3
# 9                    163           3
# 12                   151           3
# 2                    147           3
# 5                    147           3
# 10                   144           3
# 32                   120           3

# %%
conv3d_root_nodes = [node for node in tree.cpu_root_nodes if tree.events_by_uid[node]['name'] == 'aten::conv3d']
print(f"Found {len(conv3d_root_nodes)} root nodes")

df_conv3d_ops = perf_analyzer.build_df_perf_metrics(conv3d_root_nodes, bwd=False)
perf_analyzer.summarize_df_perf_metrics(df_conv3d_ops, ['mean'])
# Out:
# Found 16 root nodes
#            name     param: input_shape param: filter_shape param: stride  \
# 5  aten::conv3d  (10, 32, 1, 480, 640)   (16, 32, 1, 3, 3)     (1, 1, 1)
# 6  aten::conv3d    (10, 64, 1, 60, 80)   (64, 64, 1, 3, 3)     (1, 1, 1)
# 3  aten::conv3d  (10, 32, 1, 240, 320)   (32, 32, 1, 3, 3)     (1, 1, 1)
# 1  aten::conv3d  (10, 16, 1, 480, 640)   (16, 16, 1, 3, 3)     (1, 1, 1)
# 4  aten::conv3d  (10, 32, 1, 480, 640)   (16, 32, 1, 1, 1)     (1, 1, 1)
# 0  aten::conv3d  (10, 16, 1, 480, 640)    (3, 16, 1, 3, 3)     (1, 1, 1)
# 8  aten::conv3d  (10, 64, 1, 120, 160)   (32, 64, 1, 3, 3)     (1, 1, 1)
# 2  aten::conv3d  (10, 32, 1, 120, 160)   (32, 32, 1, 3, 3)     (1, 1, 1)
# 7  aten::conv3d  (10, 64, 1, 120, 160)   (32, 64, 1, 1, 1)     (1, 1, 1)
#
#   param: padding param: dilation  param: groups  param: bias  \
# 5      (0, 0, 0)       (1, 1, 1)              1        False
# 6      (0, 0, 0)       (1, 1, 1)              1        False
# 3      (0, 0, 0)       (1, 1, 1)              1        False
# 1      (0, 0, 0)       (1, 1, 1)              1        False
# 4      (0, 0, 0)       (1, 1, 1)              1        False
# 0      (0, 0, 0)       (1, 1, 1)              1        False
# 8      (0, 0, 0)       (1, 1, 1)              1        False
# 2      (0, 0, 0)       (1, 1, 1)              1        False
# 7      (0, 0, 0)       (1, 1, 1)              1        False
#
#    param: transposed_conv  GFLOPS_first  FLOPS/Byte_first  TFLOPS/s_mean  \
# 5                   False     28.105482         95.530041      26.741658
# 6                   False      3.335455        277.759018      31.546537
# 3                   False     13.950075        142.919099      42.518127
# 1                   False     14.052741         71.735324      21.356749
# 4                   False      3.145728         10.666630       6.241524
# 0                   False      2.634889         22.597151       5.333783
# 8                   False      6.872924        188.067305      43.499520
# 2                   False      3.436462        141.776473      29.882279
# 7                   False      0.786432         21.330963       9.252141
#
#    Kernel Time (µs)_sum  name_count
# 5                  1051           1
# 6                   758           7
# 3                   659           2
# 1                   658           1
# 4                   504           1
# 0                   494           1
# 8                   158           1
# 2                   115           1
# 7                    85           1

# %%
# conv3d bwd
df_conv3d_bwd_ops = perf_analyzer.build_df_perf_metrics(conv3d_root_nodes, bwd=True)
perf_analyzer.summarize_df_perf_metrics(df_conv3d_bwd_ops, ['mean'])
